# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Bing5154/AI4AV/blob/master/Matrix_Operation.ipynb)

# %%
# http://pytorch.org/
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu90' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.0-{platform}-linux_x86_64.whl torchvision
import torch

# %%
from google.colab import files
uploaded = files.upload() # then browse, select the files. It's then uploaded
# Out:
#      <input type="file" id="files-a9707ed4-4630-4e7b-b471-e0251a7be1a7" name="files[]" multiple disabled />
#      <output id="result-a9707ed4-4630-4e7b-b471-e0251a7be1a7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving plot_conf.py to plot_conf (1).py

# %%
# %run ~/plot_conf.py

# %%
# Set style (need to be in a new cell)
plt_style()
import torch
import torch.nn as nn
from torch.autograd import Variable
import matplotlib.pyplot as plt


# utility function
def show_scatterplot(X, norm=True, title=''):
    X = X.numpy()
    plt.figure()
    plt.axis('equal')
    plt.scatter(X[:, 0], X[:, 1], s=p_size)
    if norm:
        plt.xlim(-6, 6)
        plt.ylim(-6, 6)
    plt.grid(True)
    plt.title(title)


# generate some points in 2-D space
n_points = 500
p_size = 30
X = np.array([[np.cos(theta),0.5*np.sin(theta)] for theta in np.linspace(0,2*np.pi,n_points)]).reshape((n_points,2))
X = torch.from_numpy(X)
show_scatterplot(X, norm=True, title='X')

# %%
I = torch.DoubleTensor([[1,0],[0, 1]])
X_R = X @ I
show_scatterplot(X_R, norm=True, title='X_R')
