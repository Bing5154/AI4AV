# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Bing5154/AI4AV/blob/master/Image_Processing.ipynb)

# %%
from scipy import signal
from scipy import misc
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import files
uploaded = files.upload() # then browse, select the files. It's then uploaded
# choose Bikesgray.jpg and # choose plot_conf.py
# Out:
#      <input type="file" id="files-a0adb81a-2d10-47cd-9b71-775dc783ed46" name="files[]" multiple disabled />
#      <output id="result-a0adb81a-2d10-47cd-9b71-775dc783ed46">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving peppers.jpg to peppers.jpg

# %%
# %run ~/plot_conf.py
plt_style('w')

# %%
imgB = np.array(Image.open('/content/Bikesgray.jpg'))
imgC = np.array(Image.open('/content/peppers.jpg'))

# %%
print(imgB.shape)
print(imgC.shape)
# Out:
# (480, 640)
# (384, 512, 3)

# %%
plt.imshow(img, cmap='gray')
